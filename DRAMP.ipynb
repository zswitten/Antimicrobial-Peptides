# %%
import re
import requests
from bs4 import BeautifulSoup
DATABASE_NAME = 'DRAMP'
ANTIBACTERIA_LINK_PAGES = 326
bacteria_regex = r'(?P<bacterium>[A-Z]\. [a-z]+)(?P<strain>\s?[A-Z]+\s?[0-9]+)?'

# %%
# Find links to each DRAMP peptide page
find_links_base = 'http://dramp.cpu-bioinfor.org/browse/ActivityData.php?order=antibacterial&pageNow='
drampids = []
for i in range(1, ANTIBACTERIA_LINK_PAGES):
    url = find_links_base + str(i)
    content = requests.get(url).content
    soup = BeautifulSoup(content, 'html.parser')
    matches = re.finditer('value\=\"(?P<drampid>DRAMP[0-9]+)\"', str(soup))
    drampids += [m.groupdict()['drampid'] for m in matches]

# %%
# Get a list of bacteria names
bacteria_list_url_base = 'http://www.thelabrat.com/protocols/Bacterialspecies/byname'
bacteria_names = []
import string
for letter in string.ascii_uppercase:
    url = bacteria_list_url_base + letter + '.shtml'
    content = requests.get(url).content
    soup = BeautifulSoup(content, 'html.parser')
    text = soup.text
    # start = text.index('Y | Z \n\n\') + len("Y | Z \n\n")
    end = start + text[start:].index('\n\n<!--\ngoogle_ad_client')
    for name in text[start:end].split('\n'):
        if name and name.strip() and all(c.isalpha() or c == ' ' for c in name):
            bacteria_names.append(name)

# %%
bacteria_list_url_base_2 = 'https://www.ncbi.nlm.nih.gov/books/NBK'
for i in range(818, 844):
    url = bacteria_list_url_base_2 + str(i)
    content = requests.get(url).content
    soup = BeautifulSoup(content, 'html.parser')
    str_soup = str(soup)
    for match in re.finditer('targettype=tax', str_soup):
        start = match.start()
        while str_soup[start] != '>':
            start += 1
        start += 1
        end = start
        while str_soup[end] != '<':
            end += 1
        if str_soup[start].isupper():
            bacteria_names.append(str_soup[start:end])

# %%
bacteria_names = list(set(bacteria_names + bnames))

# %%
import pickle
pickle.dump(bacteria_names, open("bacteria_list.txt", "w"))

# %%
def get_line_splits(soup):
    text = soup.text
    while text != text.replace('\n\n', '\n'):
        text = text.replace('\n\n', '\n')
    return text.split('\n')

def get_sequence(soup_split_by_line):
    return soup_split_by_line[soup_split_by_line.index('Sequence Length') - 1]

def get_modifications(soup):
    ptm_string = '"comments-PTM">PTM</h4></li><li><h5> '
    text = str(soup)
    if ptm_string not in text:
        return []
    rest = text[text.index(ptm_string) + len(ptm_string):]
    ptm = rest[:rest.index('</')]
    if 'erminal amidation' not in rest:
        return ["Unknown modification: " + ptm]
    return ['C-Terminal Amidation']

def get_references(soup_split_by_line):
    references = []
    reference_splits = soup_split_by_line[soup_split_by_line.index('Literature Information'):]
    for i, line in enumerate(reference_splits):
        if line == 'Reference':
            pubmed_id = reference_splits[i - 1]
            reference = reference_splits[i + 3]
            author = reference_splits[i + 1]
            title = reference_splits[i + 5]
            references.append(
                "PubMed ID: %s. Reference: %s. Author: %s. Title: %s"
                % (pubmed_id, reference, author, title)
            )
    return references

def find_longest_bacteria_matches(bacteria_names, text_section):
    # Find bacteria names that match, using only longest form
    # This way we don't keep the one-word abbreviations when two names are present
    bacteria_matches = [b for b in bacteria_names if ' ' + b in text_section.lower()]
    longest_matches = []
    for match in bacteria_matches:
        is_sub = False
        for other_match in bacteria_matches:
            if match in other_match and len(other_match) > len(match):
                is_sub = True
        if not is_sub:
            longest_matches.append(match)
    return longest_matches

def bacteria_text_to_bacteria_and_strain(bacteria_names, line):
    all_matches = []
    matches_from_full_names = find_longest_bacteria_matches(bacteria_names, line)

    strain = re.search('ATCC\s?[0-9]+', line)
    if strain:
        strain = strain.group(0)

    for match in matches_from_full_names:
        if len(match.split()) > 1:
            try:
                all_matches.append((
                    match[0].upper() + '. ' + match.split()[1],
                    strain.strip() if strain else ''
                ))
            except:
                print("????", match, line)
        else:
            splits = line.lower().split()
            for i, split in enumerate(splits):
                if split == match:
                    try:
                        all_matches.append((
                            match[0].upper() + '. ' + splits[i + 1],
                            strain.strip() if strain else ''
                        ))
                    except:
                        print("?????????", match, line)
            
    for regex_match in re.finditer(bacteria_regex, line):
        bacterium = regex_match.groupdict()['bacterium']
        strain = regex_match.groupdict()['strain']
        all_matches.append((
            bacterium,
            strain.strip() if strain else ''
        ))

    return all_matches

def extract_unit_and_value(line):
    value = re.search('[0-9]+\.?[0-9]*', line)
    if not value:
        return ('', '')
    unit = line[value.end():].strip().replace(')', '')
    return (value.group(0), unit)

def get_mic_data(soup_split_by_line, _bacteria_names):
    bacteria_names_lower = [b.lower() for b in bacteria_names]
    all_bacteria = {}
    mic_line_index = sorted(
        [i for i in range(len(soup_split_by_line)) if soup_split_by_line[i] == 'Target Organism']
    )[1] + 1
    mic_line = soup_split_by_line[mic_line_index]
    bacterium_or_unit_and_value_fields = re.split('(\(MIC\s?.*?\))', mic_line)  # Alternating between unit/values and bacteria
    for i, mic_split in enumerate(bacterium_or_unit_and_value_fields):
        if re.search('(\(MIC\s?.*?\))', mic_split):
            bacteria_and_strains = bacteria_text_to_bacteria_and_strain(bacteria_names_lower, bacterium_or_unit_and_value_fields[i - 1])
            unit, value = extract_unit_and_value(mic_split)
            for (bacterium, strain) in bacteria_and_strains:
                all_bacteria[(bacterium, strain)] = {
                    'unit': unit,
                    'value': value
                }
    return all_bacteria

def get_hemolysis_data(soup):  # Return the sentence with the hemolytic data, leaving parsing for later
    text = soup.text
    if 'hemoly' in text:
        for sentence in text.split('.'):
            if 'hemoly' in sentence:
                return sentence
    return None

# %%
amps = {}

# %%
def parse_soup(soup):
    ssplits = get_line_splits(soup)
    sequence = get_sequence(ssplits)
    if not sequence:
        return None, None
    if 'Patent Information' in str(soup):
        print('Patent Information')
        return None, None
    modifications = get_modifications(soup)
    references = get_references(ssplits)
    mic_data = get_mic_data(ssplits, bacteria_names)
    url_sources = [url]
    hemolysis_data = get_hemolysis_data(soup)
    return (
        sequence, 
        {
            'modifications': modifications,
            'references': references,
            'bacteria': mic_data,
            'url_sources': url_sources,
            'hemolysis': hemolysis_data,
        }
    )

# %%
"""url = 'http://dramp.cpu-bioinfor.org/browse/All_Information.php?id=DRAMP01474&dataset='
content = requests.get(url).content
soup = BeautifulSoup(content, 'html.parser')
parse_soup(soup)"""
# Out:
# "url = 'http://dramp.cpu-bioinfor.org/browse/All_Information.php?id=DRAMP01474&dataset='\ncontent = requests.get(url).content\nsoup = BeautifulSoup(content, 'html.parser')\nparse_soup(soup)"

# %%
for i, drampid in enumerate(drampids[len(amps):]):
    url = url_base + drampid
    content = requests.get(url).content
    soup = BeautifulSoup(content, 'html.parser')

    ssplits = get_line_splits(soup)

    sequence = get_sequence(ssplits)
    if not sequence:
        continue

    sequence, results = parse_soup(soup)
    if sequence:
        amps[sequence] = results

    if i % 10 == 0:
        print(i)
# Out:
# 0
# 10
# Patent Information
# Patent Information
# 20
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 30
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 40
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 50
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 60
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 70
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 80
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 90
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 100
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 110
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 120
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 130
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 140
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 150
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 160
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 170
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 180
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 190
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 200
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 210
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 220
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 230
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 240
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 250
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 260
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 270
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 280
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 290
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 300
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 310
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 320
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 330
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 340
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 350
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 360
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 370
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 380
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 390
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 400
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 410
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 420
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 430
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 440
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 450
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 460
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 470
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 480
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 490
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 500
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 510
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 520
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 530
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 540
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 550
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 560
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 570
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 580
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 590
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 600
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 610
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 620
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 630
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 640
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 650
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 660
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 670
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 680
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 690
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 700
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 710
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 720
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 730
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 740
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 750
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 760
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 770
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 780
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 790
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 800
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 810
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 820
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 830
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 840
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 850
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 860
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 870
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 880
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 890
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 900
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 910
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 920
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 930
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 940
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 950
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 960
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 970
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 980
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 990
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1000
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1010
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1020
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1030
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1040
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1050
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1060
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1070
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1080
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1090
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1100
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1110
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1120
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1130
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1140
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1150
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1160
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1170
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1180
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1190
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1200
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1210
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1220
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1230
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1240
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1250
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1260
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1270
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1280
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1290
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1300
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1310
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1320
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1330
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1340
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1350
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1360
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1370
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1380
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1390
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1400
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1410
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1420
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1430
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1440
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1450
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1460
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1470
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1480
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1490
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1500
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1510
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1520
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1530
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1540
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1550
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1560
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1570
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1580
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1590
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1600
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1610
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1620
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1630
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1640
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1650
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1660
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1670
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1680
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1690
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1700
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1710
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1720
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1730
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1740
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1750
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1760
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1770
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1780
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1790
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1800
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1810
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1820
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1830
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1840
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1850
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1860
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1870
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1880
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1890
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1900
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1910
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1920
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1930
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1940
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1950
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1960
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1970
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1980
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 1990
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2000
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2010
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2020
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2030
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2040
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2050
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2060
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2070
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2080
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2090
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2100
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2110
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2120
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2130
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2140
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2150
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2160
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2170
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2180
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2190
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2200
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2210
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2220
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2230
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2240
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2250
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2260
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2270
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2280
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2290
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2300
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2310
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2320
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2330
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2340
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2350
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2360
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2370
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2380
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2390
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2400
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2410
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2420
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2430
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2440
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2450
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2460
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2470
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2480
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# ...
# Patent Information
# Patent Information
# 2820
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2830
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2840
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2850
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2860
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2870
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2880
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2890
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2900
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2910
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2920
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2930
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2940
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2950
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2960
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2970
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2980
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 2990
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3000
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3010
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3020
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3030
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3040
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3050
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3060
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3070
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3080
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3090
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3100
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3110
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3120
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3130
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3140
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3150
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3160
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3170
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3180
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3190
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3200
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3210
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3220
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3230
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3240
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3250
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3260
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3270
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3280
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3290
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3300
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3310
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3320
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3330
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3340
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3350
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3360
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3370
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# Patent Information
# 3380
# Patent Information
# Patent Information
# Patent Information
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-372-afa8d13df721> in <module>()
#       1 for i, drampid in enumerate(drampids[len(amps):]):
#       2     url = url_base + drampid
# ----> 3     content = requests.get(url).content
#       4     soup = BeautifulSoup(content, 'html.parser')
#       5
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     628
#     629         # Resolve redirects if allowed.
# --> 630         history = [resp for resp in gen] if allow_redirects else []
#     631
#     632         # Shuffle things around if there's history.
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/sessions.pyc in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     188                 proxies=proxies,
#     189                 allow_redirects=False,
# --> 190                 **adapter_kwargs
#     191             )
#     192
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     377         try:
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
with open(DATABASE_NAME + ".data", 'w') as f:
    f.write(str(amps))

# %%
len(amps)
# Out:
# 2985
